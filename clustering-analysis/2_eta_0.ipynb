# %% [markdown]
#     1) Перемешать магнитуды и времена событий
#     2) Вычислить значения NND для всех пар событий
#     3) Использовать 1-й процентиль как оценку для eta_0
#         -> Обратите внимание, что eta_0 необходима для разделения
#            кластерных и фоновых событий на следующих этапах анализа
#     4) eta_0 сохраняется в директории /data
#        имя файла: [имя_файла]_Mc_[порог_магнитуды]_eta_0.txt

# %%
import matplotlib as mpl
#mpl.use( 'Agg') # отключить интерактивные графики
import matplotlib.pyplot as plt
import numpy as np
import scipy.io
import os

#------------------------------мои модули--------------------------------------
import src.clustering as clustering
import src.data_utils as data_utils
from   src.EqCat import *

# %%
# Создаем объекты для работы с каталогами землетрясений:
eqCat   = EqCat()    # оригинальный каталог
ranCat  = EqCat()    # рандомизированный (пуассоновский) каталог
eqCatMc = EqCat()    # каталог с событиями выше порога полноты
np.random.seed( 123456)  # фиксируем случайные числа для воспроизводимости

# %%
#=================================1==============================================
#                            директории, файлы, параметры
#================================================================================
dir_in = 'data'                    # директория с данными
file_in= 'NEIC_Global_1900_2025_2011_Tohoku.mat'    # входной файл с данными о землетрясениях

# %%
# Параметры анализа
dPar  = {   
    'aMc'         :  np.array([3.0, 4.0]),  # пороговые значения магнитуд (Mc)
    # фрактальная размерность (D) и b-значение для формулы (1)
    'D'           : 1.6,  # TODO: эти значения должны быть определены на основе данных
    'b'           : 1.3333398574492394,  # b-значение (лучше вычислить отдельно)
    
    # количество бутстреп-итераций для рандомизированных каталогов
    'nBoot' : 100,
    #=================параметры построения графиков================
    'eta_binsize' :  .3,  # размер ячейки гистограммы
    
    'cmin' : 1, 
    'xmin' : -13, 'xmax' : 0,  # диапазон по оси X для гистограммы
    ## Параметры для графика "время-расстояние" (T-R plot)
    'binx' : .1, 'biny' : .1,  # размер ячеек для плотности и сглаживания
    'sigma'   : None,  # ширина полосы Гаусса (если None - автоматически)
    'Tmin' :  -8, 'Tmax' : 0,  # диапазон по времени
    'Rmin' :  -5, 'Rmax' : 3,  # диапазон по расстоянию
    'cmap'        : plt.cm.RdYlGn_r,  # цветовая схема
    'showPlot'    :  False,  # показывать ли графики (для отладки)
}

# %%
#================================================================================
#                      загрузка данных, отбор событий
#================================================================================
# Загружаем данные из бинарного файла .mat
eqCat.loadMatBin(  os.path.join( dir_in, file_in))
print( 'общее количество событий', eqCat.size())
print( eqCat.data)

# Отбираем события с магнитудой выше начального порога
eqCat.selectEvents( dPar['aMc'][0], None, 'Mag')
print( 'количество событий после начального отбора', eqCat.size())

# Преобразуем географические координаты в декартовы (для вычисления расстояний)
eqCat.toCart_coordinates( projection = 'eqdc')  # эквидистантная проекция

# Цикл по разным порогам магнитуды (Mc)
for f_Mc in dPar['aMc']:
    print( '-------------- текущий порог Mc:', f_Mc, '---------------------')
    
    # Создаем подкаталог только с событиями выше текущего порога Mc
    eqCatMc.copy( eqCat)
    eqCatMc.selectEvents( f_Mc, None, 'Mag')
    print( 'размер каталога после отбора по магнитуде', eqCat.size())
    
    # Словарь констант для использования в модуле кластеризации
    dConst = {'Mc' : f_Mc,
               'b' : dPar['b'],
               'D' : dPar['D']}

    #=============================2===================================================
    #                    рандомизация каталога (бутстреп)
    #=================================================================================
    # Массив для хранения значений eta_0 из каждой итерации
    a_Eta_0 = np.zeros( dPar['nBoot'])
    
    # Цикл по бутстреп-итерациям
    for i_Bs in range( dPar['nBoot']):
        # Копируем оригинальный каталог
        ranCat.copy( eqCatMc)
        
        # Рандомизируем пространственные координаты (X, Y) и время
        ranCat.data['X']     = np.random.uniform( eqCatMc.data['X'].min(), eqCatMc.data['X'].max(), size = eqCatMc.size())
        ranCat.data['Y']     = np.random.uniform( eqCatMc.data['Y'].min(), eqCatMc.data['Y'].max(), size = eqCatMc.size())
        ranCat.data['Time']  = clustering.rand_rate_uni( eqCatMc.size(), eqCatMc.data['Time'].min(), eqCatMc.data['Time'].max())
        ranCat.sortCatalog( 'Time')  # сортируем по времени
        
        #==================================3=============================================
        #     вычисляем расстояния до ближайшего соседа (NND) для рандомизированного каталога
        #================================================================================
        dNND = clustering.NND_eta( ranCat, dConst,  M0 = 0,   correct_co_located = True,
                                   verbose = False)
        
        # Вычисляем 1-й процентиль логарифмов расстояний - это и есть eta_0 для данной итерации
        a_Eta_0[i_Bs] = round( np.percentile( np.log10(dNND['aNND']), 1), 5)
        print( 'итерация', i_Bs+1,'из', dPar['nBoot'], 'eta_0 - 1-й процентиль:', np.percentile( np.log10(dNND['aNND']), 1))
        
        # Если включено отображение графиков - показываем промежуточные результаты
        if dPar['showPlot'] == True:
            #=================================4==============================================
            #                          строим гистограмму NND
            #================================================================================
            plt.figure( 1, figsize = (10,5))
            ax = plt.axes( [.12, .12, .83, .83])
            # Строим гистограмму логарифмов расстояний
            ax.hist( np.log10( dNND['aNND']), np.arange( dPar['xmin'], dPar['xmax'], dPar['eta_binsize']),
                            color = '.5', label = 'Mc = %.1f'%( f_Mc), align = 'mid', rwidth=.9)
            
            # Отмечаем характерные значения на графике
            ax.plot( [-5, -5], ax.get_ylim(), 'w-',  lw = 2, )
            ax.plot( [-5, -5], ax.get_ylim(), 'k--', lw = 2, )
            ax.plot( [a_Eta_0[i_Bs], a_Eta_0[i_Bs]], ax.get_ylim(), 'w-',  lw = 2, label = '$N_\mathrm{tot}$=%i'%( ranCat.size()))
            ax.plot( [a_Eta_0[i_Bs], a_Eta_0[i_Bs]], ax.get_ylim(), 'r--', lw = 2, label = '$N_\mathrm{cl}$=%i'%( dNND['aNND'][dNND['aNND']<1e-5].shape[0]))

            ax.legend( loc = 'upper left')
            ax.set_xlabel( 'NND, log$_{10} \eta$')
            ax.set_ylabel( 'Количество событий')
            ax.grid( 'on')
            ax.set_xlim( dPar['xmin'], dPar['xmax'])

            #==================================4==============================================================
            #                           плотностной график T-R (время-расстояние)
            #=================================================================================================
            # Создаем отдельные каталоги для родительских и дочерних событий
            catChild = EqCat()
            catParent= EqCat()
            catChild.copy(  ranCat)
            catParent.copy( ranCat)

            # Отбираем события по ID родительских и дочерних пар
            catChild.selEventsFromID(    dNND['aEqID_c'], repeats = True)
            catParent.selEventsFromID(   dNND['aEqID_p'], repeats = True)
            print( catChild.size(), catParent.size(), eqCatMc.size())
            
            # Вычисляем масштабированные времена и расстояния
            a_R, a_T = clustering.rescaled_t_r( catChild, catParent, dConst, correct_co_located = True)

            # Создаем сетку для плотностного графика
            a_Tbin = np.arange( dPar['Tmin'], dPar['Tmax']+2*dPar['binx'], dPar['binx'])
            a_Rbin = np.arange( dPar['Rmin'], dPar['Rmax']+2*dPar['biny'], dPar['biny'])
            a_log_T = np.log10( a_T)
            a_log_R = np.log10( a_R)
            
            # Вычисляем двумерную плотность
            XX, YY, ZZ = data_utils.density_2D( a_log_T, a_log_R, a_Tbin, a_Rbin, sigma = dPar['sigma'])

            # Строим плотностной график
            plt.figure(2, figsize= (8,10))
            ax = plt.subplot(111)
            ax.set_title( 'Пары ближайших соседей на графике Время-Расстояние')
            
            # Отображаем плотность цветом
            normZZ = ZZ*( dPar['binx']*dPar['biny']*eqCatMc.size())
            plot1 = ax.pcolormesh( XX, YY, normZZ, cmap=dPar['cmap'])
            cbar  = plt.colorbar(plot1, orientation = 'horizontal', shrink = .5, aspect = 20,)
            
            # Рисуем линию, разделяющую кластерные и фоновые события
            ax.plot( [dPar['Tmin'], dPar['Tmax']],  -np.array([dPar['Tmin'], dPar['Tmax']])+a_Eta_0[i_Bs], '-', lw = 1.5, color = 'w' )
            ax.plot( [dPar['Tmin'], dPar['Tmax']],  -np.array([dPar['Tmin'], dPar['Tmax']])+a_Eta_0[i_Bs],'--', lw = 1.5, color = '.5' )
            
            # Настройка подписей
            cbar.set_label( 'Количество пар событий',labelpad=-40)
            ax.set_xlabel( 'Масштабированное время')
            ax.set_ylabel( 'Масштабированное расстояние')
            ax.set_xlim( dPar['Tmin'], dPar['Tmax'])
            ax.set_ylim( dPar['Rmin'], dPar['Rmax'])

            plt.show()
# Out:
# общее количество событий 1926
# {'YR': array([2011., 2011., 2011., ..., 2011., 2011., 2011.], shape=(1926,)), 'MO': array([3., 3., 3., ..., 5., 5., 5.], shape=(1926,)), 'DY': array([10., 10., 10., ...,  9.,  9.,  9.], shape=(1926,)), 'HR': array([ 7.,  8.,  8., ..., 15., 19., 21.], shape=(1926,)), 'MN': array([33.,  8., 59., ...,  4., 13., 39.], shape=(1926,)), 'SC': array([ 4.7, 20.5, 19.8, ..., 23.3, 25.9, 30.2], shape=(1926,)), 'ID': array([189972, 189973, 189974, ..., 193194, 193199, 193203], shape=(1926,)), 'Lat': array([37.723, 38.233, 37.635, ..., 37.12 , 35.24 , 35.23 ], shape=(1926,)), 'Lon': array([142.023, 143.278, 142.74 , ..., 144.067, 142.342, 141.362],
#       shape=(1926,)), 'Depth': array([35.7, 44.8, 30.7, ..., 10. , 10. , 35. ], shape=(1926,)), 'Mag': array([4.5, 4.5, 4.8, ..., 4.6, 4.6, 4.7], shape=(1926,)), 'Time': array([2011.18716337, 2011.18723044, 2011.18732747, ..., 2011.35240557,
#        2011.35287941, 2011.35315731], shape=(1926,))}
# количество событий после начального отбора 1926
# -------------- текущий порог Mc: 3.0 ---------------------
# размер каталога после отбора по магнитуде 1926
# 1 %i events with NND=0
# итерация 1 из 100 eta_0 - 1-й процентиль: -9.22680643343625
# 1 %i events with NND=0
# итерация 2 из 100 eta_0 - 1-й процентиль: -9.03139021588516
# 2 %i events with NND=0
# итерация 3 из 100 eta_0 - 1-й процентиль: -9.079538716312518
# 1 %i events with NND=0
# итерация 4 из 100 eta_0 - 1-й процентиль: -9.328845559727581
# 2 %i events with NND=0
# итерация 5 из 100 eta_0 - 1-й процентиль: -9.287855186857316
# 1 %i events with NND=0
# итерация 6 из 100 eta_0 - 1-й процентиль: -9.244852498056915
# 2 %i events with NND=0
# итерация 7 из 100 eta_0 - 1-й процентиль: -9.300718927942759
# 1 %i events with NND=0
# итерация 8 из 100 eta_0 - 1-й процентиль: -9.305497835313036
# 1 %i events with NND=0
# итерация 9 из 100 eta_0 - 1-й процентиль: -9.160930160182366
# 3 %i events with NND=0
# итерация 10 из 100 eta_0 - 1-й процентиль: -9.166792564940609
# 1 %i events with NND=0
# итерация 11 из 100 eta_0 - 1-й процентиль: -9.164965485391127
# 2 %i events with NND=0
# итерация 12 из 100 eta_0 - 1-й процентиль: -9.130584672868254
# 2 %i events with NND=0
# итерация 13 из 100 eta_0 - 1-й процентиль: -9.398110338303397
# 2 %i events with NND=0
# итерация 14 из 100 eta_0 - 1-й процентиль: -9.212747678130858
# 2 %i events with NND=0
# итерация 15 из 100 eta_0 - 1-й процентиль: -9.212514957187206
# 1 %i events with NND=0
# итерация 16 из 100 eta_0 - 1-й процентиль: -9.222488805032176
# 2 %i events with NND=0
# итерация 17 из 100 eta_0 - 1-й процентиль: -9.542758842911812
# 2 %i events with NND=0
# итерация 18 из 100 eta_0 - 1-й процентиль: -9.136179360925041
# 2 %i events with NND=0
# итерация 19 из 100 eta_0 - 1-й процентиль: -9.44115959026481
# 3 %i events with NND=0
# итерация 20 из 100 eta_0 - 1-й процентиль: -9.225981037170701
# 1 %i events with NND=0
# итерация 21 из 100 eta_0 - 1-й процентиль: -9.128232289790633
# 3 %i events with NND=0
# итерация 22 из 100 eta_0 - 1-й процентиль: -9.145115088767907
# 2 %i events with NND=0
# итерация 23 из 100 eta_0 - 1-й процентиль: -9.032119540294815
# 2 %i events with NND=0
# итерация 24 из 100 eta_0 - 1-й процентиль: -9.14786250371618
# 1 %i events with NND=0
# итерация 25 из 100 eta_0 - 1-й процентиль: -9.266235448793038
# 2 %i events with NND=0
# итерация 26 из 100 eta_0 - 1-й процентиль: -9.32190690542306
# 2 %i events with NND=0
# итерация 27 из 100 eta_0 - 1-й процентиль: -9.038146327567368
# 2 %i events with NND=0
# итерация 28 из 100 eta_0 - 1-й процентиль: -9.270238025153434
# 1 %i events with NND=0
# итерация 29 из 100 eta_0 - 1-й процентиль: -9.149301110081645
# 3 %i events with NND=0
# итерация 30 из 100 eta_0 - 1-й процентиль: -9.226776979047102
# 1 %i events with NND=0
# итерация 31 из 100 eta_0 - 1-й процентиль: -9.34577156425765
# 1 %i events with NND=0
# итерация 32 из 100 eta_0 - 1-й процентиль: -9.286002906874963
# 1 %i events with NND=0
# итерация 33 из 100 eta_0 - 1-й процентиль: -9.340057552071176
# 2 %i events with NND=0
# итерация 34 из 100 eta_0 - 1-й процентиль: -9.319298323707757
# 2 %i events with NND=0
# итерация 35 из 100 eta_0 - 1-й процентиль: -9.042024697717567
# 3 %i events with NND=0
# итерация 36 из 100 eta_0 - 1-й процентиль: -9.251555126938424
# 1 %i events with NND=0
# итерация 37 из 100 eta_0 - 1-й процентиль: -9.252968801075566
# 2 %i events with NND=0
# итерация 38 из 100 eta_0 - 1-й процентиль: -9.397221477940107
# 1 %i events with NND=0
# итерация 39 из 100 eta_0 - 1-й процентиль: -9.142665273381134
# 2 %i events with NND=0
# итерация 40 из 100 eta_0 - 1-й процентиль: -9.110553859197614
# 2 %i events with NND=0
# итерация 41 из 100 eta_0 - 1-й процентиль: -9.310916387350934
# 1 %i events with NND=0
# итерация 42 из 100 eta_0 - 1-й процентиль: -9.308920991478116
# 2 %i events with NND=0
# итерация 43 из 100 eta_0 - 1-й процентиль: -9.25702986818935
# 1 %i events with NND=0
# итерация 44 из 100 eta_0 - 1-й процентиль: -9.14679856458191
# 3 %i events with NND=0
# итерация 45 из 100 eta_0 - 1-й процентиль: -9.153505684634355
# 1 %i events with NND=0
# итерация 46 из 100 eta_0 - 1-й процентиль: -9.228248163373552
# 1 %i events with NND=0
# итерация 47 из 100 eta_0 - 1-й процентиль: -9.349468836595912
# 1 %i events with NND=0
# итерация 48 из 100 eta_0 - 1-й процентиль: -9.45975860882439
# 1 %i events with NND=0
# итерация 49 из 100 eta_0 - 1-й процентиль: -9.501222940005759
# 1 %i events with NND=0
# итерация 50 из 100 eta_0 - 1-й процентиль: -9.262817672637949
# 2 %i events with NND=0
# итерация 51 из 100 eta_0 - 1-й процентиль: -9.329819628805934
# 2 %i events with NND=0
# итерация 52 из 100 eta_0 - 1-й процентиль: -9.231362735788373
# 1 %i events with NND=0
# итерация 53 из 100 eta_0 - 1-й процентиль: -9.095817754957322
# 2 %i events with NND=0
# итерация 54 из 100 eta_0 - 1-й процентиль: -9.154207125161038
# 1 %i events with NND=0
# итерация 55 из 100 eta_0 - 1-й процентиль: -9.141428404285044
# 2 %i events with NND=0
# итерация 56 из 100 eta_0 - 1-й процентиль: -9.219757176435847
# 2 %i events with NND=0
# итерация 57 из 100 eta_0 - 1-й процентиль: -9.286366245908855
# 2 %i events with NND=0
# итерация 58 из 100 eta_0 - 1-й процентиль: -9.239233821233624
# 2 %i events with NND=0
# итерация 59 из 100 eta_0 - 1-й процентиль: -9.065236161494337
# 2 %i events with NND=0
# итерация 60 из 100 eta_0 - 1-й процентиль: -9.242733736262366
# 2 %i events with NND=0
# итерация 61 из 100 eta_0 - 1-й процентиль: -9.245759946269322
# 1 %i events with NND=0
# итерация 62 из 100 eta_0 - 1-й процентиль: -9.200844850277802
# 1 %i events with NND=0
# итерация 63 из 100 eta_0 - 1-й процентиль: -9.17560333985806
# 1 %i events with NND=0
# итерация 64 из 100 eta_0 - 1-й процентиль: -9.255413762302554
# 2 %i events with NND=0
# итерация 65 из 100 eta_0 - 1-й процентиль: -9.207517707071396
# 2 %i events with NND=0
# итерация 66 из 100 eta_0 - 1-й процентиль: -9.161725105246536
# 1 %i events with NND=0
# итерация 67 из 100 eta_0 - 1-й процентиль: -9.1398191205443
# 1 %i events with NND=0
# итерация 68 из 100 eta_0 - 1-й процентиль: -9.225901765706839
# 2 %i events with NND=0
# итерация 69 из 100 eta_0 - 1-й процентиль: -9.297145614600492
# 2 %i events with NND=0
# итерация 70 из 100 eta_0 - 1-й процентиль: -9.120011007482852
# 1 %i events with NND=0
# итерация 71 из 100 eta_0 - 1-й процентиль: -9.26238452207493
# 1 %i events with NND=0
# итерация 72 из 100 eta_0 - 1-й процентиль: -9.147960219221979
# 2 %i events with NND=0
# итерация 73 из 100 eta_0 - 1-й процентиль: -9.45916662804126
# 2 %i events with NND=0
# итерация 74 из 100 eta_0 - 1-й процентиль: -9.181782857727399
# 2 %i events with NND=0
# итерация 75 из 100 eta_0 - 1-й процентиль: -9.363863376913862
# 1 %i events with NND=0
# итерация 76 из 100 eta_0 - 1-й процентиль: -9.160533920838018
# 2 %i events with NND=0
# итерация 77 из 100 eta_0 - 1-й процентиль: -9.190958950649552
# 1 %i events with NND=0
# итерация 78 из 100 eta_0 - 1-й процентиль: -9.261560169410147
# 1 %i events with NND=0
# итерация 79 из 100 eta_0 - 1-й процентиль: -9.236265184725147
# 2 %i events with NND=0
# итерация 80 из 100 eta_0 - 1-й процентиль: -9.243932444880897
# 2 %i events with NND=0
# итерация 81 из 100 eta_0 - 1-й процентиль: -9.33212067928328
# 1 %i events with NND=0
# итерация 82 из 100 eta_0 - 1-й процентиль: -9.212475014330696
# 1 %i events with NND=0
# итерация 83 из 100 eta_0 - 1-й процентиль: -9.271292646849089
# 2 %i events with NND=0
# итерация 84 из 100 eta_0 - 1-й процентиль: -9.167454329953262
# 3 %i events with NND=0
# итерация 85 из 100 eta_0 - 1-й процентиль: -9.136050322679635
# 2 %i events with NND=0
# итерация 86 из 100 eta_0 - 1-й процентиль: -9.228839263318266
# 1 %i events with NND=0
# итерация 87 из 100 eta_0 - 1-й процентиль: -9.13220267949568
# 3 %i events with NND=0
# итерация 88 из 100 eta_0 - 1-й процентиль: -9.247541216381723
# 1 %i events with NND=0
# итерация 89 из 100 eta_0 - 1-й процентиль: -9.08388923069858
# 2 %i events with NND=0
# итерация 90 из 100 eta_0 - 1-й процентиль: -9.3528453418162
# 2 %i events with NND=0
# итерация 91 из 100 eta_0 - 1-й процентиль: -9.311741033876768
# 1 %i events with NND=0
# итерация 92 из 100 eta_0 - 1-й процентиль: -9.207434938565894
# 2 %i events with NND=0
# итерация 93 из 100 eta_0 - 1-й процентиль: -9.239169582057583
# 2 %i events with NND=0
# итерация 94 из 100 eta_0 - 1-й процентиль: -9.144054322030959
# 2 %i events with NND=0
# итерация 95 из 100 eta_0 - 1-й процентиль: -9.238462269913033
# 2 %i events with NND=0
# итерация 96 из 100 eta_0 - 1-й процентиль: -9.22017955289666
# 2 %i events with NND=0
# итерация 97 из 100 eta_0 - 1-й процентиль: -9.358222416296055
# 1 %i events with NND=0
# итерация 98 из 100 eta_0 - 1-й процентиль: -9.376782431094473
# 3 %i events with NND=0
# итерация 99 из 100 eta_0 - 1-й процентиль: -9.207144562296653
# 2 %i events with NND=0
# итерация 100 из 100 eta_0 - 1-й процентиль: -9.18006746247475
# -------------- текущий порог Mc: 4.0 ---------------------
# размер каталога после отбора по магнитуде 1926
# 1 %i events with NND=0
# итерация 1 из 100 eta_0 - 1-й процентиль: -9.172440267997835
# 2 %i events with NND=0
# итерация 2 из 100 eta_0 - 1-й процентиль: -9.090415432233886
# 1 %i events with NND=0
# итерация 3 из 100 eta_0 - 1-й процентиль: -9.251169712756791
# 1 %i events with NND=0
# итерация 4 из 100 eta_0 - 1-й процентиль: -9.147032932481142
# 1 %i events with NND=0
# итерация 5 из 100 eta_0 - 1-й процентиль: -9.379506819175067
# 1 %i events with NND=0
# итерация 6 из 100 eta_0 - 1-й процентиль: -9.076928589629789
# 1 %i events with NND=0
# итерация 7 из 100 eta_0 - 1-й процентиль: -9.243069902939828
# 1 %i events with NND=0
# итерация 8 из 100 eta_0 - 1-й процентиль: -9.193210641232481
# 1 %i events with NND=0
# итерация 9 из 100 eta_0 - 1-й процентиль: -9.057488495715136
# 2 %i events with NND=0
# итерация 10 из 100 eta_0 - 1-й процентиль: -9.269600071279239
# 1 %i events with NND=0
# итерация 11 из 100 eta_0 - 1-й процентиль: -9.269023352750686
# 2 %i events with NND=0
# итерация 12 из 100 eta_0 - 1-й процентиль: -9.175173433339332
# 2 %i events with NND=0
# итерация 13 из 100 eta_0 - 1-й процентиль: -9.324440050532232
# 2 %i events with NND=0
# итерация 14 из 100 eta_0 - 1-й процентиль: -9.373978320040857
# 1 %i events with NND=0
# итерация 15 из 100 eta_0 - 1-й процентиль: -9.163977828834497
# 2 %i events with NND=0
# итерация 16 из 100 eta_0 - 1-й процентиль: -9.172879370043015
# 1 %i events with NND=0
# итерация 17 из 100 eta_0 - 1-й процентиль: -9.256945725364137
# 1 %i events with NND=0
# итерация 18 из 100 eta_0 - 1-й процентиль: -9.2386050897462
# 2 %i events with NND=0
# итерация 19 из 100 eta_0 - 1-й процентиль: -9.422820252281909
# 2 %i events with NND=0
# итерация 20 из 100 eta_0 - 1-й процентиль: -9.324227155029714
# 3 %i events with NND=0
# итерация 21 из 100 eta_0 - 1-й процентиль: -9.252548829314438
# 1 %i events with NND=0
# итерация 22 из 100 eta_0 - 1-й процентиль: -9.121413843168975
# 2 %i events with NND=0
# итерация 23 из 100 eta_0 - 1-й процентиль: -9.193679123312688
# 1 %i events with NND=0
# итерация 24 из 100 eta_0 - 1-й процентиль: -9.206140538317483
# 1 %i events with NND=0
# итерация 25 из 100 eta_0 - 1-й процентиль: -9.24329673200167
# 1 %i events with NND=0
# итерация 26 из 100 eta_0 - 1-й процентиль: -9.120235570710527
# 2 %i events with NND=0
# итерация 27 из 100 eta_0 - 1-й процентиль: -9.175707501272067
# 3 %i events with NND=0
# итерация 28 из 100 eta_0 - 1-й процентиль: -9.120487493818265
# 2 %i events with NND=0
# итерация 29 из 100 eta_0 - 1-й процентиль: -9.269361947926107
# 1 %i events with NND=0
# итерация 30 из 100 eta_0 - 1-й процентиль: -9.296517909841219
# 1 %i events with NND=0
# итерация 31 из 100 eta_0 - 1-й процентиль: -9.208667732249904
# 1 %i events with NND=0
# итерация 32 из 100 eta_0 - 1-й процентиль: -9.309701674017283
# 2 %i events with NND=0
# итерация 33 из 100 eta_0 - 1-й процентиль: -9.212365345477519
# 2 %i events with NND=0
# итерация 34 из 100 eta_0 - 1-й процентиль: -9.363406370144656
# 2 %i events with NND=0
# итерация 35 из 100 eta_0 - 1-й процентиль: -9.277654549327725
# 2 %i events with NND=0
# итерация 36 из 100 eta_0 - 1-й процентиль: -9.362852105010607
# 2 %i events with NND=0
# итерация 37 из 100 eta_0 - 1-й процентиль: -9.431625037094815
# 1 %i events with NND=0
# итерация 38 из 100 eta_0 - 1-й процентиль: -9.232470015516538
# 2 %i events with NND=0
# итерация 39 из 100 eta_0 - 1-й процентиль: -9.46335902353984
# 1 %i events with NND=0
# итерация 40 из 100 eta_0 - 1-й процентиль: -9.168205496644152
# 1 %i events with NND=0
# итерация 41 из 100 eta_0 - 1-й процентиль: -9.134953920275143
# 1 %i events with NND=0
# итерация 42 из 100 eta_0 - 1-й процентиль: -9.220632356704137
# 1 %i events with NND=0
# итерация 43 из 100 eta_0 - 1-й процентиль: -9.192161660919428
# 1 %i events with NND=0
# итерация 44 из 100 eta_0 - 1-й процентиль: -9.341438215390074
# 3 %i events with NND=0
# итерация 45 из 100 eta_0 - 1-й процентиль: -9.289315976582113
# 2 %i events with NND=0
# итерация 46 из 100 eta_0 - 1-й процентиль: -9.201468448793522
# 2 %i events with NND=0
# итерация 47 из 100 eta_0 - 1-й процентиль: -9.384769111500473
# 2 %i events with NND=0
# итерация 48 из 100 eta_0 - 1-й процентиль: -9.25133515309151
# 2 %i events with NND=0
# итерация 49 из 100 eta_0 - 1-й процентиль: -9.065425207914993
# 1 %i events with NND=0
# итерация 50 из 100 eta_0 - 1-й процентиль: -9.176419778296424
# 2 %i events with NND=0
# итерация 51 из 100 eta_0 - 1-й процентиль: -9.106536140512592
# 1 %i events with NND=0
# итерация 52 из 100 eta_0 - 1-й процентиль: -9.397175130516457
# 2 %i events with NND=0
# итерация 53 из 100 eta_0 - 1-й процентиль: -9.075627198813397
# 1 %i events with NND=0
# итерация 54 из 100 eta_0 - 1-й процентиль: -9.142220844823512
# 1 %i events with NND=0
# итерация 55 из 100 eta_0 - 1-й процентиль: -9.26471759383274
# 1 %i events with NND=0
# итерация 56 из 100 eta_0 - 1-й процентиль: -9.369685000304028
# 2 %i events with NND=0
# итерация 57 из 100 eta_0 - 1-й процентиль: -9.257992274855479
# 2 %i events with NND=0
# итерация 58 из 100 eta_0 - 1-й процентиль: -9.271419542258034
# 1 %i events with NND=0
# итерация 59 из 100 eta_0 - 1-й процентиль: -9.076391933001437
# 1 %i events with NND=0
# итерация 60 из 100 eta_0 - 1-й процентиль: -9.145905075388946
# 2 %i events with NND=0
# итерация 61 из 100 eta_0 - 1-й процентиль: -9.521442935538067
# 1 %i events with NND=0
# итерация 62 из 100 eta_0 - 1-й процентиль: -9.12690868067105
# 1 %i events with NND=0
# итерация 63 из 100 eta_0 - 1-й процентиль: -9.12449081678445
# 2 %i events with NND=0
# итерация 64 из 100 eta_0 - 1-й процентиль: -9.435601630770977
# 1 %i events with NND=0
# итерация 65 из 100 eta_0 - 1-й процентиль: -9.193378163409893
# 1 %i events with NND=0
# итерация 66 из 100 eta_0 - 1-й процентиль: -9.371311587677344
# 1 %i events with NND=0
# итерация 67 из 100 eta_0 - 1-й процентиль: -9.17538482662615
# 2 %i events with NND=0
# итерация 68 из 100 eta_0 - 1-й процентиль: -9.111105892746368
# 2 %i events with NND=0
# итерация 69 из 100 eta_0 - 1-й процентиль: -9.221777827732126
# 2 %i events with NND=0
# итерация 70 из 100 eta_0 - 1-й процентиль: -9.210059779974573
# 1 %i events with NND=0
# итерация 71 из 100 eta_0 - 1-й процентиль: -9.311578325715574
# 2 %i events with NND=0
# итерация 72 из 100 eta_0 - 1-й процентиль: -9.379724341107034
# 1 %i events with NND=0
# итерация 73 из 100 eta_0 - 1-й процентиль: -9.341699169766944
# 2 %i events with NND=0
# итерация 74 из 100 eta_0 - 1-й процентиль: -9.209817986838157
# 3 %i events with NND=0
# итерация 75 из 100 eta_0 - 1-й процентиль: -9.24510211228761
# 2 %i events with NND=0
# итерация 76 из 100 eta_0 - 1-й процентиль: -9.22439858358434
# 2 %i events with NND=0
# итерация 77 из 100 eta_0 - 1-й процентиль: -9.292232324272502
# 2 %i events with NND=0
# итерация 78 из 100 eta_0 - 1-й процентиль: -9.326095321455115
# 2 %i events with NND=0
# итерация 79 из 100 eta_0 - 1-й процентиль: -9.155935778953406
# 1 %i events with NND=0
# итерация 80 из 100 eta_0 - 1-й процентиль: -9.4054968409331
# 1 %i events with NND=0
# итерация 81 из 100 eta_0 - 1-й процентиль: -9.126701816196146
# 2 %i events with NND=0
# итерация 82 из 100 eta_0 - 1-й процентиль: -9.317820579141543
# 2 %i events with NND=0
# итерация 83 из 100 eta_0 - 1-й процентиль: -9.18265625411119
# 1 %i events with NND=0
# итерация 84 из 100 eta_0 - 1-й процентиль: -9.33952939765966
# 1 %i events with NND=0
# итерация 85 из 100 eta_0 - 1-й процентиль: -9.176056313640062
# 2 %i events with NND=0
# итерация 86 из 100 eta_0 - 1-й процентиль: -9.233771478182156
# 2 %i events with NND=0
# итерация 87 из 100 eta_0 - 1-й процентиль: -9.19856759013062
# 2 %i events with NND=0
# итерация 88 из 100 eta_0 - 1-й процентиль: -9.256567743721961
# 1 %i events with NND=0
# итерация 89 из 100 eta_0 - 1-й процентиль: -9.423500459181891
# 1 %i events with NND=0
# итерация 90 из 100 eta_0 - 1-й процентиль: -9.240272115874706
# 1 %i events with NND=0
# итерация 91 из 100 eta_0 - 1-й процентиль: -9.186425947104155
# 1 %i events with NND=0
# итерация 92 из 100 eta_0 - 1-й процентиль: -9.24869206054298
# 2 %i events with NND=0
# итерация 93 из 100 eta_0 - 1-й процентиль: -9.2232911105134
# 1 %i events with NND=0
# итерация 94 из 100 eta_0 - 1-й процентиль: -9.267239897840494
# 3 %i events with NND=0
# итерация 95 из 100 eta_0 - 1-й процентиль: -9.234913803490715
# 1 %i events with NND=0
# итерация 96 из 100 eta_0 - 1-й процентиль: -9.27494664991585
# 1 %i events with NND=0
# итерация 97 из 100 eta_0 - 1-й процентиль: -9.073320357217893
# 1 %i events with NND=0
# итерация 98 из 100 eta_0 - 1-й процентиль: -9.268644687558481
# 3 %i events with NND=0
# итерация 99 из 100 eta_0 - 1-й процентиль: -9.19655019994392
# 2 %i events with NND=0
# итерация 100 из 100 eta_0 - 1-й процентиль: -9.0850107112938

# %%
eqCat.data
# Out:
# {'YR': array([2011., 2011., 2011., ..., 2011., 2011., 2011.], shape=(1926,)),
#  'MO': array([3., 3., 3., ..., 5., 5., 5.], shape=(1926,)),
#  'DY': array([10., 10., 10., ...,  9.,  9.,  9.], shape=(1926,)),
#  'HR': array([ 7.,  8.,  8., ..., 15., 19., 21.], shape=(1926,)),
#  'MN': array([33.,  8., 59., ...,  4., 13., 39.], shape=(1926,)),
#  'SC': array([ 4.7, 20.5, 19.8, ..., 23.3, 25.9, 30.2], shape=(1926,)),
#  'ID': array([189972, 189973, 189974, ..., 193194, 193199, 193203], shape=(1926,)),
#  'Lat': array([37.723, 38.233, 37.635, ..., 37.12 , 35.24 , 35.23 ], shape=(1926,)),
#  'Lon': array([142.023, 143.278, 142.74 , ..., 144.067, 142.342, 141.362],
#        shape=(1926,)),
#  'Depth': array([35.7, 44.8, 30.7, ..., 10. , 10. , 35. ], shape=(1926,)),
#  'Mag': array([4.5, 4.5, 4.8, ..., 4.6, 4.6, 4.7], shape=(1926,)),
#  'Time': array([2011.18716337, 2011.18723044, 2011.18732747, ..., 2011.35240557,
#         2011.35287941, 2011.35315731], shape=(1926,)),
#  'X': array([346.96091948, 456.8081962 , 410.0586517 , ..., 527.92645627,
#         374.84023981, 285.73409618], shape=(1926,)),
#  'Y': array([404.42470002, 461.42573271, 394.62575185, ..., 338.62447658,
#         128.26184148, 127.67545203], shape=(1926,))}

# %%
    #=================================3==============================================
    #                            сохраняем результаты
    #================================================================================
    # Вычисляем среднее значение eta_0 по всем бутстреп-итерациям
    f_eta_0 = a_Eta_0.mean()
    print( 'среднее значение eta_0', a_Eta_0.mean())
    
    # Формируем имя выходного файла
    file_out = '%s/%s_Mc_%.1f_eta_0.txt'%(dir_in, file_in, f_Mc)
    
    # Сохраняем среднее значение eta_0 в текстовый файл
    np.savetxt( file_out, np.array([f_eta_0]), fmt = '%10.3f', header='eta_0')
    print( 'результаты сохранены в', file_out)
    
    # Также сохраняем в формате .mat для дальнейшего использования
    scipy.io.savemat(file_out.replace('txt','mat'),
                     {'eta_0': f_eta_0, 'eta_BS' : a_Eta_0,}, do_compression=True)
# Out:
# среднее значение eta_0 -9.239363200000001
# результаты сохранены в data/NEIC_Global_1900_2025_2011_Tohoku.mat_Mc_4.0_eta_0.txt
